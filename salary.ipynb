# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

dataset = pd.read_csv('C:/Users/민지/Downloads/Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
dataset.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
plt.scatter(dataset['YearsExperience'], dataset['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Prediction')

plt.show()

# %%
X=dataset['Salary']
y=dataset['YearsExperience']

X=X.to_numpy()
y=y.to_numpy()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.25,
                                                 random_state=0)

X_train=X_train.reshape(-1, 1)
X_test=X_test.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)
y_pred
# Out:
# array([1.372477  , 9.85265035, 3.31071648, 3.9254439 , 9.30954262,
#        8.55448065, 8.87541705, 3.18180101])

# %%
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, lr.predict(X_train), color='blue')
plt.title("Salary vs Experience(Training set)")

plt.xlabel("Years of experience")
plt.ylabel("Salaries")
plt.show()

# %%
lr.score(X_test, y_test)
# Out:
# 0.974376290571024

# %%
from sklearn.metrics import mean_absolute_error

y_prediction=lr.predict(X_test)
mae=mean_absolute_error(y_test, y_prediction)
print(mae)
# Out:
# 0.40854484439547784

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [0.00010017] -2.4069397347271453

# %%
print(lr.predict([[10]]))
# Out:
# [-2.40593806]

# %%
plt.scatter(X_train, y_train)

plt.plot([0, 30], [lr.coef_+lr.intercept_, 50*lr.coef_+lr.intercept_])
plt.scatter(50, 1241.8, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
